# %%
# !pip uninstall -y tensorflow
# Out:
# Found existing installation: tensorflow 2.17.1
# Uninstalling tensorflow-2.17.1:
#   Successfully uninstalled tensorflow-2.17.1

# %%
# !pip install tensorflow==2.17.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 601.3/601.3 MB 2.7 MB/s eta 0:00:000:00:010:01m
# ...

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.17.0

# %%
# !pip install ultralytics==8.3.45 --no-deps
# !pip install opencv-python-headless==4.10.0.84 --no-deps
# !pip install pillow==11.0.0 --no-deps
# !pip install thop --no-deps
# Out:
# ERROR: Ignored the following yanked versions: 8.0.12, 8.0.15, 8.0.129, 8.0.174, 8.0.177, 8.1.21, 8.1.31, 8.2.7, 8.2.47
# ...

# %%
# !pip install ultralytics -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 19.1 MB/s eta 0:00:00a 0:00:01

# %%
from ultralytics import YOLO

# Check if the library is installed
print("Ultralytics installed successfully!")
# Out:
# Ultralytics installed successfully!

# %%
# !pip install gdown # https://drive.google.com/file/d/1dJtWCZf4hVQcrM2nLUb9vg-oN6c0LDDm/view?usp=drive_link
# !gdown 1dJtWCZf4hVQcrM2nLUb9vg-oN6c0LDDm
# Out:
# ...
# Downloading...
# From (original): https://drive.google.com/uc?id=1dJtWCZf4hVQcrM2nLUb9vg-oN6c0LDDm
# From (redirected): https://drive.google.com/uc?id=1dJtWCZf4hVQcrM2nLUb9vg-oN6c0LDDm&confirm=t&uuid=e4514246-024e-4039-81c2-3972466d872e
# To: /kaggle/working/final_dataset.zip
# 100%|██████████████████████████████████████| 1.22G/1.22G [00:17<00:00, 71.1MB/s]

# %%
import zipfile
import os

zip_path = "/kaggle/working/final_dataset.zip"  # Replace with your actual ZIP file name
extract_path = "/kaggle/working"

# Extract the ZIP file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# Delete the ZIP file after extraction
os.remove(zip_path)

print("Extraction completed and ZIP file deleted!")
# Out:
# Extraction completed and ZIP file deleted!

# %%
import yaml

def update_yaml_content(file_path, new_content):
    try:
        # Write the new content to the YAML file
        with open(file_path, 'w') as file:
            yaml.dump(new_content, file)

        print("File updated successfully.")
    except Exception as e:
        print(f"An error occurred: {e}")

# Define the yaml file path
file_path = '/kaggle/working/data.yaml'

# Define the new content
new_content = {
    'names': ['currency'], 
    'nc': 1,  
    'test': '/kaggle/working/final_dataset/test/images', 
    'train': '/kaggle/working/final_dataset/train/images', 
    'val': '/kaggle/working/final_dataset/valid/images'
}

# Call the function to update the YAML file
update_yaml_content(file_path, new_content)
# Out:
# File updated successfully.

# %%
import yaml

def view_yaml_file(file_path):
    with open(file_path, 'r') as file:
        yaml_content = yaml.safe_load(file)
        return yaml_content

file_path = "/kaggle/working/data.yaml"
yaml_content = view_yaml_file(file_path)
print(yaml_content)
# Out:
# {'names': ['currency'], 'nc': 1, 'test': '/kaggle/working/final_dataset/test/images', 'train': '/kaggle/working/final_dataset/train/images', 'val': '/kaggle/working/final_dataset/valid/images'}

# %%
from ultralytics import YOLO

# Build a YOLOv9c model from scratch
model = YOLO('yolov10n.yaml')

# Build a YOLOv9c model from pretrained weight
model = YOLO('yolov10n.pt')

# Display model information (optional)
model.info()
# Out:
# YOLOv10n summary: 223 layers, 2,775,520 parameters, 0 gradients, 8.7 GFLOPs
# (223, 2775520, 0, 8.7404288)

# %%
results = model.train(data='/kaggle/working/data.yaml', epochs=50,
                    batch=32,patience=10,cache=True,save_period=30,imgsz=300)
# Out:
# Ultralytics 8.3.235 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
import shutil

# Compress the folder
shutil.make_archive('training_results_yolov10', 'zip', '/kaggle/working/runs/detect/train3')

# Download the zip file from the "Files" tab
# Out:
# '/kaggle/working/training_results_yolov10.zip'

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/kaggle/working/runs/detect/train3/weights/best.pt")

# Perform object detection on an image
results = model("/kaggle/working/final_dataset/test/images/100_10.jpg", save=True)
results[0].show()
# Out:
# image 1/1 /kaggle/working/final_dataset/test/images/100_10.jpg: 320x320 1 currency, 8.6ms
# Speed: 1.3ms preprocess, 8.6ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 320)
# Results saved to /kaggle/working/runs/detect/predict
# <PIL.Image.Image image mode=RGB size=1500x1500>
